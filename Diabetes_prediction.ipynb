# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# 3                     0.365   24        1
# 4                     0.536   21        0

# %%
df.shape
# Out:
# (2000, 9)

# %%
df.describe()
# Out:
#        Pregnancies      Glucose  BloodPressure  SkinThickness      Insulin  \
# count  2000.000000  2000.000000    2000.000000    2000.000000  2000.000000
# mean      3.703500   121.182500      69.145500      20.935000    80.254000
# std       3.306063    32.068636      19.188315      16.103243   111.180534
# min       0.000000     0.000000       0.000000       0.000000     0.000000
# 25%       1.000000    99.000000      63.500000       0.000000     0.000000
# 50%       3.000000   117.000000      72.000000      23.000000    40.000000
# 75%       6.000000   141.000000      80.000000      32.000000   130.000000
# max      17.000000   199.000000     122.000000     110.000000   744.000000
#
#                BMI  DiabetesPedigreeFunction          Age      Outcome
# count  2000.000000               2000.000000  2000.000000  2000.000000
# mean     32.193000                  0.470930    33.090500     0.342000
# std       8.149901                  0.323553    11.786423     0.474498
# ...

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    1316
# 1     684
# Name: count, dtype: int64

# %%
df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness    Insulin  \
# Outcome
# 0           3.168693  110.586626      68.094985      20.052432  70.563830
# 1           4.732456  141.568713      71.166667      22.633041  98.897661
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.567477                  0.434676  31.081307
# 1        35.320468                  0.540681  36.956140

# %%
X = df.drop(columns = 'Outcome', axis=1)
Y = df['Outcome']

# %%
X
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age
# 0                        0.127   47
# ...

# %%
Y
#0 means no diabetes
#1 means patient with diabetes
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 1995    0
# 1996    1
# 1997    0
# 1998    1
# 1999    0
# Name: Outcome, Length: 2000, dtype: int64

# %% [markdown]
# **Data Standardization**
# to transform data so that it has a common format and scale

# %%
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
standardized_data = scaler.transform(X)

# %%
standardized_data
# Out:
# array([[-0.5153943 ,  0.52455322, -0.37248123, ...,  0.17268332,
#         -1.06324616,  1.18042417],
#        [-1.12049474, -1.1597562 ,  0.67008046, ...,  0.73724853,
#         -0.7355513 , -0.85632626],
#        [-1.12049474,  0.74288962, -3.60442246, ...,  1.47363794,
#          0.49175869, -0.17740945],
#        ...,
#        [ 0.69480658, -1.12856529,  0.46156812, ..., -0.12187245,
#         -0.27492362,  0.75610116],
#        [-1.12049474,  0.24383498,  2.12966682, ...,  4.28419085,
#         -0.46968566, -0.60173245],
#        [-0.5153943 , -1.25332895,  0.14879962, ..., -0.25687717,
#          0.23516743, -0.68659705]])

# %%
X=standardized_data

# %%
X
# Out:
# array([[-0.5153943 ,  0.52455322, -0.37248123, ...,  0.17268332,
#         -1.06324616,  1.18042417],
#        [-1.12049474, -1.1597562 ,  0.67008046, ...,  0.73724853,
#         -0.7355513 , -0.85632626],
#        [-1.12049474,  0.74288962, -3.60442246, ...,  1.47363794,
#          0.49175869, -0.17740945],
#        ...,
#        [ 0.69480658, -1.12856529,  0.46156812, ..., -0.12187245,
#         -0.27492362,  0.75610116],
#        [-1.12049474,  0.24383498,  2.12966682, ...,  4.28419085,
#         -0.46968566, -0.60173245],
#        [-0.5153943 , -1.25332895,  0.14879962, ..., -0.25687717,
#          0.23516743, -0.68659705]])

# %%
Y
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 1995    0
# 1996    1
# 1997    0
# 1998    1
# 1999    0
# Name: Outcome, Length: 2000, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, stratify=Y, random_state=2)

# %%
classifier = svm.SVC(kernel='linear')

# %%
classifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
ytrain_predict = classifier.predict(X_train)

# %%
train_accuracy = accuracy_score(ytrain_predict, Y_train)

# %%
print('Accuracy score of the training data : ', train_accuracy)
# Out:
# Accuracy score of the training data :  0.775

# %%
ytest_predict = classifier.predict(X_test)
test_accuracy = accuracy_score(ytest_predict, Y_test)

# %%
print('Accuracy score of the test data : ', test_accuracy)
# Out:
# Accuracy score of the test data :  0.805

# %%
pd.DataFrame(data={'Actual':Y_test,'Predicted':ytest_predict}).head()
# Out:
#       Actual  Predicted
# 1604       0          0
# 1918       0          0
# 408        1          1
# 1359       0          0
# 87         0          0

# %% [markdown]
# Making a Prediction

# %%
input = (1,139,62,41,480,40.7,0.536,21)
input_array = np.asarray(input)
reshaped = input_array.reshape(1,-1)
std_data = scaler.transform(reshaped)
print(std_data)

prediction = classifier.predict(std_data)
print(prediction)

if (prediction[0] == 0):
  print('The person is not diabetic')
else:
  print('The person is diabetic')
# Out:
# [[-0.81794452  0.55574413 -0.37248123  1.24633394  3.59636675  1.04407745
#    0.20116136 -1.02605546]]
# [0]
# The person is not diabetic
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
